# %% [markdown]
# # Notebook for Capstone Project

# %% [markdown]
# ### The project focus to analyzing location data to solve problems

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
